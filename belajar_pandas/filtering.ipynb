# %% [markdown]
# Latihan untuk belajar pandas membuat filtering

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("insurance.csv")

df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# melakukan compare / perbandingan antar data
# contoh : apakah data pada kolom age yang lebih besar dari 20

# %%
df.age > 20 # menamplkan apakah true / false pada setiap baris

df[df.age > 20] # menampilkan data yang age > 20 saja
# Out:
#       age     sex     bmi  children smoker     region      charges
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# ...   ...     ...     ...       ...    ...        ...          ...
# 1331   23  female  33.400         0     no  southwest  10795.93733
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1172 rows x 7 columns]

# %% [markdown]
# menampilkan data yang mempunyai anak saja

# %%
df[~(df.children == 0)]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 8      37    male  29.830         2     no  northeast   6406.41070
# ...   ...     ...     ...       ...    ...        ...          ...
# 1328   23  female  24.225         2     no  northeast  22395.74424
# 1329   52    male  38.600         2     no  southwest  10325.20600
# 1330   57  female  25.740         2     no  southeast  12629.16560
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
#
# [764 rows x 7 columns]

# %% [markdown]
# multiple statement

# %%
df[~(df.children == 0) & (df.age < 20)]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1      18    male  33.770         1     no  southeast   1725.55230
# 15     19    male  24.600         1     no  southwest   1837.23700
# 32     19  female  28.600         5     no  southwest   4687.79700
# 46     18  female  38.665         2     no  northeast   3393.35635
# 57     18    male  31.680         2    yes  southeast  34303.16720
# 106    19  female  28.400         1     no  southwest   2331.51900
# 149    19    male  28.400         1     no  southwest   1842.51900
# 168    19  female  31.825         1     no  northwest   2719.27975
# 248    19    male  20.900         1     no  southwest   1832.09400
# 250    18    male  17.290         2    yes  northeast  12829.45510
# 270    18    male  29.370         1     no  southeast   1719.43630
# 276    19    male  20.615         2     no  northwest   2803.69785
# 369    18    male  30.400         3     no  northeast   3481.86800
# ...

# %%
df[(df.region.isin(["northwest", "southeast"]) | (~(df.children == 0) & (df.age < 20)))]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# ...   ...     ...     ...       ...    ...        ...          ...
# 1327   51    male  30.030         1     no  southeast   9377.90470
# 1330   57  female  25.740         2     no  southeast  12629.16560
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [702 rows x 7 columns]

# %% [markdown]
# tetapi ingat itu hanya menampilkan datanya saja untuk menyimpannya menjadi dataframe baru maka harus disimpan di variable baru dan ditambahkan di belakangnya .copy() untuk menjaga dataframe yang asli

# %% [markdown]
# Melakukan sorting
#
# ascending => melakukan pengurutan dari bawah ke atas

# %%
df.sort_values("age", ascending = True)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1248   18  female  39.820         0     no  southeast   1633.96180
# 482    18  female  31.350         0     no  southeast   1622.18850
# 492    18  female  25.080         0     no  northeast   2196.47320
# 525    18  female  33.880         0     no  southeast  11482.63485
# 529    18    male  25.460         0     no  northeast   1708.00140
# ...   ...     ...     ...       ...    ...        ...          ...
# 398    64    male  25.600         2     no  southwest  14988.43200
# 335    64    male  34.500         0     no  southwest  13822.80300
# 378    64  female  30.115         3     no  northwest  16455.70785
# 1265   64    male  23.760         0    yes  southeast  26926.51440
# 635    64    male  38.190         0     no  northeast  14410.93210
#
# [1338 rows x 7 columns]

# %% [markdown]
# melakukan groupby -> pemisahan antar baris data berdasarkan kelompok tertentu
# lalu hasil penggabungannya bisa berasal mean(), median(), atau count()

# %%
numerik_df = df.drop(columns=["sex", "smoker"]).copy()

numerik_df.groupby("region").mean()
# Out:
#                  age        bmi  children       charges
# region
# northeast  39.268519  29.173503  1.046296  13406.384516
# northwest  39.196923  29.199785  1.147692  12417.575374
# southeast  38.939560  33.355989  1.049451  14735.411438
# southwest  39.455385  30.596615  1.141538  12346.937377

# %% [markdown]
# dengan menggunakan 2 tipe kategorikal

# %%
new_numerik_df = df.drop(columns=["smoker"]).copy()

new_numerik_df.groupby(["region", "sex"]).median()
# Out:
#                    age      bmi  children      charges
# region    sex
# northeast female  40.0  29.1650       1.0  10197.77220
#           male    39.0  28.8800       1.0   9957.72160
# northwest female  40.0  28.9275       1.0   9614.07290
#           male    38.0  28.8800       1.0   8413.46305
# southeast female  39.0  32.2300       1.0   8582.30230
#           male    39.0  34.1000       1.0   9504.31030
# southwest female  40.0  29.7500       1.0   8530.83700
#           male    39.0  30.8000       1.0   9391.34600

# %% [markdown]
# melakukan pivot table yakni menentukan table baris, kolom, values berdasarkan kolom data sebelumnya

# %%
df.pivot_table(index= "region", columns="sex", values="bmi", aggfunc="mean")
# Out:
# sex           female       male
# region
# northeast  29.324317  29.024540
# northwest  29.277957  29.120155
# southeast  32.671257  33.990000
# southwest  30.060494  31.129448

# %% [markdown]
# membuat kolom baru dan menghilangkan kolom

# %%
df["new_columns"] = np.random.rand(len(df))
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  new_columns
# 0   19  female  27.900         0    yes  southwest  16884.92400     0.665058
# 1   18    male  33.770         1     no  southeast   1725.55230     0.744013
# 2   28    male  33.000         3     no  southeast   4449.46200     0.537904
# 3   33    male  22.705         0     no  northwest  21984.47061     0.393019
# 4   32    male  28.880         0     no  northwest   3866.85520     0.566271

# %%
df.drop(columns="new_columns", inplace=True)
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# Map, Apply, dan Transform

# %% [markdown]
# map, yakni membuat value kolom sesuai value object / kategori kolom lain

# %%
df["category_region"] = df.region.map({'southwest': 1, 'southeast':2, 'northwest':3, 'northeast': 4})
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  \
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
#
#    category_region
# 0                1
# 1                2
# 2                2
# 3                3
# 4                3

# %% [markdown]
# membuat value kolom sesuai dengan kolom lain yang sudah dimasukkan di dalam function

# %%
def convert_yes_no_to_numerik(x):
    if x == "yes":
        return 1
    else:
        return 0

# %%
df["num_smoker"] = df.smoker.apply(convert_yes_no_to_numerik)

df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  \
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
#
#    category_region  num_smoker
# 0                1           1
# 1                2           0
# 2                2           0
# 3                3           0
# 4                3           0

# %% [markdown]
# apply juga dapat dimasukkan lambda function

# %%
df["bmi_kuadrat"] = df.bmi.apply(lambda x: x*x)
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  \
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
#
#    category_region  num_smoker  bmi_kuadrat
# 0                1           1   778.410000
# 1                2           0  1140.412900
# 2                2           0  1089.000000
# 3                3           0   515.517025
# 4                3           0   834.054400

# %% [markdown]
# transform yakni pengubahan x menjadi numerik tertentu misal kita ingin menjadikan value age baru menjadi value 0-1

# %%
df['scaled_age'] = df.age.transform(lambda x: (x-x.min())/(x.max()-x.min()))
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  \
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
#
#    category_region  num_smoker  bmi_kuadrat  scaled_age
# 0                1           1   778.410000    0.021739
# 1                2           0  1140.412900    0.000000
# 2                2           0  1089.000000    0.217391
# 3                3           0   515.517025    0.326087
# 4                3           0   834.054400    0.304348
